# %%
# Necessary packages
# !pip install numpy pandas matplotlib seaborn scipy statsmodels mrcfile
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.5/23.5 MB 14.8 MB/s  0:00:01 eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.1/10.1 MB 19.8 MB/s  0:00:00eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4/4 [seaborn]m3/4 [seaborn]els]
# ...

# %%
# Basic imports for a new notebook cell
import warnings
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Optional statistical / utility imports
import scipy as sp
import statsmodels.api as sm
import mrcfile as mrc

# Jupyter visualization and display settings
# %matplotlib inline
sns.set(style="whitegrid", context="notebook", palette="deep")
warnings.filterwarnings("ignore")
plt.rcParams.update({"figure.figsize": (10, 6), "figure.dpi": 100})
pd.set_option("display.max_columns", 200)
pd.set_option("display.max_rows", 100)

# %%
# What MRC files is analyzed 
# Alteration by user enabled 

mrc_file_path = "../data/mrc/example.mrc"  # Path to the MRC file
